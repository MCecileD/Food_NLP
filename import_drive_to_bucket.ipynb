# %% [markdown]
# <a href="https://colab.research.google.com/github/MCecileD/Food_NLP/blob/main/import_drive_to_bucket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# On monte le drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# On récupère les informations du projet GCP (buckets)

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'stoked-cosine-382607'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://foodnlp/

# %% [markdown]
# On copie les fichiers du drivre vers le bucket

# %%
from tqdm import tqdm
bucket_name = 'foodnlp'
# !gsutil -m cp -r -P /content/drive/My\ Drive/Nao_School/week8/dataset/Data_Set_Projet_2/Food_Images/Food_Images/* gs://{bucket_name}/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Copying file:///content/drive/My Drive/Nao_School/week8/dataset/Data_Set_Projet_2/Food_Images/Food_Images/peppermint-cosmo-356530.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Nao_School/week8/dataset/Data_Set_Projet_2/Food_Images/Food_Images/peppermint-cream-puff-ring-with-chocolate-glaze-233427.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Nao_School/week8/dataset/Data_Set_Projet_2/Food_Images/Food_Images/peppermint-ice-cream-candyland-cake-240698.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Nao_School/week8/dataset/Data_Set_Projet_2/Food_Images/Food_Images/peppermint-ice-cream-trifle-369113.jpg [Content-Type=image/jpeg]...
# ...
